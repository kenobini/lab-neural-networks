# %% [markdown]
# # Challenge 2: Tensorflow Hyperparameter Tuning

# %% [markdown]
# ### Screenshot

# %%
# Screenshot was added to repo as a png

# %% [markdown]
# ### Results

# %% [markdown]
# - Dataset Used: Spiral
# - Number of Epochs: 718
# - Learning Rate: 0.03
# - Activation Function: Tanh
# - Selected Features: X₁, X₂
# - Hidden Layers and Neurons:
#     - Layer 1: 6 neurons
#     - Layer 2: 5 neurons
#     - Layer 3: 4 neurons
# - Training Loss: 0.009
# - Test Loss: 0.010
# - Regularization: None
